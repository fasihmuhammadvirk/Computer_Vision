# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
image=cv2.imread('/content/g1.jpg')
image1=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
image2=cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
plt.imshow(image1)

# %%
hist=cv2.calcHist([image2], [0], None, [256], [0,255])

# %%
plt.plot(hist)

# %%
e_hist=cv2.equalizeHist(image2)
image3=cv2.cvtColor(e_hist,cv2.COLOR_GRAY2BGR)

# %%
hist1=cv2.calcHist([e_hist], [0], None, [256], [0,255])

# %%
plt.plot(hist1)

# %%
plt.imshow(image3)

# %%
plt.imshow(image1)

# %%
img = cv2.imread('/content/image1.jpg')
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.show()

# %%
img = cv2.imread('/content/image1.jpg')
r,g,b=cv2.split(img)
hist=cv2.calcHist([b], [0], None, [256], [0,255])
plt.plot(hist)
hist=cv2.calcHist([g], [0], None, [256], [0,255])
plt.plot(hist)
hist=cv2.calcHist([r], [0], None, [256], [0,255])
plt.plot(hist)
